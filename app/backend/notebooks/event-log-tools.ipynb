# %%
# %load_ext autoreload
# %autoreload 2
import os
if not hasattr(__builtins__, '_cwd_set'):
    os.chdir('..')
    __builtins__._cwd_set = True
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import pm4py

# %%
df_log = pd.read_csv('examples/TJSP-BL-event-log.csv')
df_log
# Out:
#                        lawsuit_id        date  \
# 0       0000536-07.2020.8.26.0003  01/06/2020
# 1       0000536-07.2020.8.26.0003  01/06/2020
# 2       0000536-07.2020.8.26.0003  01/06/2020
# 3       0000536-07.2020.8.26.0003  26/05/2020
# 4       0000536-07.2020.8.26.0003  20/05/2020
# ...                           ...         ...
# 266829  1134599-20.2018.8.26.0100  07/01/2019
# 266830  1134599-20.2018.8.26.0100  07/01/2019
# 266831  1134599-20.2018.8.26.0100  07/01/2019
# 266832  1134599-20.2018.8.26.0100  07/01/2019
# 266833  1134599-20.2018.8.26.0100  28/12/2018
#
#                                                  movement  order  \
# 0                                  Conclusos para Decisão      2
# 1                                 Conclusos para Despacho      1
# 2                           Certidão de Cartório Expedida      0
# 3                                      Suspensão do Prazo      0
# 4                                      Suspensão do Prazo      0
# ...                                                   ...    ...
# 266829                      Certidão de Cartório Expedida      3
# 266830                                       Guia Juntada      2
# 266831                                Notificação Juntada      1
# 266832  Contrato Social/Atos Constitutivos/Carta de Pr...      0
# 266833  Distribuído Livremente (por Sorteio) (moviment...      0
#
#                     status   area subject_matter      control     digital  \
# 0                      NaN  Cível       Franquia  2020/000087  VERDADEIRO
# 1                      NaN  Cível       Franquia  2020/000087  VERDADEIRO
# 2                      NaN  Cível       Franquia  2020/000087  VERDADEIRO
# 3                      NaN  Cível       Franquia  2020/000087  VERDADEIRO
# 4                      NaN  Cível       Franquia  2020/000087  VERDADEIRO
# ...                    ...    ...            ...          ...         ...
# 266829  Em grau de recurso  Cível          Marca  2018/001126       FALSO
# 266830  Em grau de recurso  Cível          Marca  2018/001126       FALSO
# 266831  Em grau de recurso  Cível          Marca  2018/001126       FALSO
# 266832  Em grau de recurso  Cível          Marca  2018/001126       FALSO
# 266833  Em grau de recurso  Cível          Marca  2018/001126       FALSO
#
#                            class distribution_date  \
# 0       Procedimento Comum Cível  04/02/2020 13:06
# 1       Procedimento Comum Cível  04/02/2020 13:06
# 2       Procedimento Comum Cível  04/02/2020 13:06
# 3       Procedimento Comum Cível  04/02/2020 13:06
# 4       Procedimento Comum Cível  04/02/2020 13:06
# ...                          ...               ...
# 266829  Procedimento Comum Cível  28/12/2018 18:09
# 266830  Procedimento Comum Cível  28/12/2018 18:09
# 266831  Procedimento Comum Cível  28/12/2018 18:09
# 266832  Procedimento Comum Cível  28/12/2018 18:09
# 266833  Procedimento Comum Cível  28/12/2018 18:09
#
#                                          court_department claim_amount  \
# 0       2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...    17.284,24
# 1       2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...    17.284,24
# 2       2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...    17.284,24
# 3       2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...    17.284,24
# 4       2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...    17.284,24
# ...                                                   ...          ...
# 266829  2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...   100.000,00
# 266830  2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...   100.000,00
# 266831  2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...   100.000,00
# 266832  2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...   100.000,00
# 266833  2ª VARA EMPRESARIAL E CONFLITOS DE ARBITRAGEM ...   100.000,00
#
#                      judge
# 0       NBJH56504647452616
# 1       NBJH56504647452616
# 2       NBJH56504647452616
# 3       NBJH56504647452616
# 4       NBJH56504647452616
# ...                    ...
# 266829  HEKK33273625011808
# 266830  HEKK33273625011808
# 266831  HEKK33273625011808
# 266832  HEKK33273625011808
# 266833  HEKK33273625011808
#
# [266834 rows x 14 columns]
